# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

df = pd.read_csv('D:\Projects\ML (University)\cardio_train1.csv',sep=";")

# %%
#print(df.head(10))
print(df.shape)
df.isna().sum()
# Out:
# (70000, 13)
# id             0
# age            1
# gender         0
# height         0
# weight         1
# ap_hi          0
# ap_lo          1
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         1
# cardio         0
# dtype: int64

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  69999.000000  70000.000000  70000.000000  69999.000000
# mean   49972.419900  19468.892184      1.349571    164.359229     74.205579
# std    28851.302323   2467.259426      0.476838      8.210126     14.395829
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  69999.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630366      1.366871      1.226457      0.088129
# ...

# %%
df["smoke"].value_counts()
# Out:
# smoke
# 0    63831
# 1     6169
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003438  0.003502 -0.003038 -0.001817  0.003356
# age          0.003438  1.000000 -0.022796 -0.081510  0.053690  0.020766
# gender       0.003502 -0.022796  1.000000  0.499033  0.155397  0.006005
# height      -0.003038 -0.081510  0.499033  1.000000  0.290965  0.005488
# weight      -0.001817  0.053690  0.155397  0.290965  1.000000  0.030701
# ap_hi        0.003356  0.020766  0.006005  0.005488  0.030701  1.000000
# ap_lo       -0.002529  0.017648  0.015254  0.006150  0.043710  0.016085
# cholesterol  0.006106  0.154419 -0.035821 -0.050226  0.141773  0.023778
# gluc         0.002467  0.098699 -0.020491 -0.018595  0.106861  0.011841
# smoke       -0.003699 -0.047636  0.338135  0.187989  0.067783 -0.000922
# alco         0.001210 -0.029726  0.170966  0.094419  0.067115  0.001408
# active       0.003767 -0.009922  0.005856 -0.006574 -0.016871 -0.000034
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(df.corr(), annot=True, fmt='.0%')
# Out:
# <Axes: >

# %%
df.drop('id', axis=1)
print(df.columns)
df(df.head(10))
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 #df.drop('id', axis=1)
#       3 print(df.columns)
# ----> 4 df(df.head(10))
#
# TypeError: 'DataFrame' object is not callable
